# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.nn import functional as F
from matplotlib import pyplot as plt
import numpy as np

# Set the random seed for reproducibility
torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Use GPU if available

# %%
# Define transformations for the training and test data
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

# Load the CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 45227366.78it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
labels = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
std = [0.2023, 0.1994, 0.2010]
mean = [0.4914, 0.4822, 0.4465]
plt.imshow(((train_features[0].permute(1, 2, 0) * np.array(std) + np.array(mean))).numpy())
plt.show()
print(f"Label: {labels[train_labels[0]]}")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Feature batch shape: torch.Size([64, 3, 32, 32])
# Labels batch shape: torch.Size([64])
# Label: truck

# %%
def conv3x3(in_planes, out_planes, stride=1):
  """3x3 convolution with padding"""
  return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                   padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
  """1x1 convolution"""
  return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)

# %%
class Block(nn.Module):

  def __init__(self, inplanes, planes, stride=1, downsample=None):
    super(Block, self).__init__()
    self.conv1 = conv1x1(inplanes, planes, stride)
    self.bn1 = nn.BatchNorm2d(planes)
    self.relu = nn.ReLU(inplace=True)
    self.conv2 = conv3x3(planes, planes)
    self.bn2 = nn.BatchNorm2d(planes)
    self.downsample = downsample
    self.stride = stride

  def forward(self, x):
    residual = x
    out = self.conv1(x)
    out = self.bn1(out)
    out = self.relu(out)
    out = self.conv2(out)
    out = self.bn2(out)

    if self.downsample is not None:
      residual = self.downsample(x)
    out += residual
    out = self.relu(out)
    return out

# %%
class ResNet(nn.Module):

  def __init__(self, n_group=1):
    super(ResNet, self).__init__()
    self.n_group = n_group

    in_channels = 3
    self.layer0 = nn.Sequential(
        nn.Conv2d(in_channels, 32, kernel_size=(3, 3), stride=1, padding=1, bias=False),
        nn.BatchNorm2d(32),
        nn.ReLU(inplace=True))

    self.inplanes = 32
    self.layer1 = self._make_layer(32,  3, [2, 2]) # [16, 16]
    self.layer2 = self._make_layer(64,  4, [2, 2]) # [8, 8]
    self.layer3 = self._make_layer(128, 6, [2, 2]) # [4, 4]
    self.layer4 = self._make_layer(256, 6, [2, 2]) # [2, 2]
    self.layer5 = self._make_layer(512, 3, [2, 2]) # [1, 1]

    self.out_planes = 512

  def _make_layer(self, planes, blocks, stride):
    downsample = None
    if stride != [1, 1] or self.inplanes != planes:
      downsample = nn.Sequential(
          conv1x1(self.inplanes, planes, stride),
          nn.BatchNorm2d(planes))

    layers = []
    layers.append(Block(self.inplanes, planes, stride, downsample))
    self.inplanes = planes
    for _ in range(1, blocks):
      layers.append(Block(self.inplanes, planes))
    return nn.Sequential(*layers)

  def forward(self, x):
    x0 = self.layer0(x)
    x1 = self.layer1(x0)
    x2 = self.layer2(x1)
    x3 = self.layer3(x2)
    x4 = self.layer4(x3)
    x5 = self.layer5(x4)

    cnn_feat = x5.squeeze(2) # [N, c, w]
    cnn_feat = cnn_feat.transpose(2, 1)
    return cnn_feat

# %%
resnet = ResNet()
resnet.to(device)
# Out:
# ResNet(
#   (layer0): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (layer1): Sequential(
#     (0): Block(
#       (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(32, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Block(
#       (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Block(
#       (conv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Block(
#       (conv1): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Block(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Block(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Block(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Block(
#       (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Block(
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Block(
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Block(
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Block(
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Block(
#       (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Block(
#       (conv1): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Block(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Block(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): Block(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): Block(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): Block(
#       (conv1): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer5): Sequential(
#     (0): Block(
#       (conv1): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Block(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): Block(
#       (conv1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )

# %%
x = resnet(train_features.to(device))
print(x.shape)
# Out:
# torch.Size([64, 1, 512])

# %%
# Define the CNN model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.batch_norm2 = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.batch_norm1(self.conv1(x))))
        x = self.pool(F.relu(self.batch_norm2(self.conv2(x))))
        x = x.view(-1, 64 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def evaluate_model(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

    return test_loss / len(test_loader)

def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs):
    losses = []
    test_losses = []
    model.train()
    num_iter = 0
    for epoch in range(num_epochs):
        running_loss = 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            num_iter += 1
            if num_iter % 100 == 0:  # Print loss every 100 iterations
                print(f'Epoch [{epoch+1}/{num_epochs}], Iteration [{num_iter}/{len(train_loader)}], Loss: {running_loss/100:.4f}')
                running_loss = 0.0
        num_iter = 0
        losses.append(running_loss / len(train_loader))
        test_loss = evaluate_model(model, test_loader, criterion)
        test_losses.append(test_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}')
        print(f'Test Loss: {test_loss:.4f}')
    return losses, test_losses

# %%
# Initialize the model, loss function, and optimizer
model = CNN()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training the model
num_epochs = 20
losses, test_losses = train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs)

# Evaluating the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the model on the 10,000 test images: {100 * correct / total:.2f}%')
# Out:
# Epoch [1/20], Iteration [100/782], Loss: 1.9455
# Epoch [1/20], Iteration [200/782], Loss: 1.6173
# Epoch [1/20], Iteration [300/782], Loss: 1.4984
# Epoch [1/20], Iteration [400/782], Loss: 1.4403
# Epoch [1/20], Iteration [500/782], Loss: 1.3790
# Epoch [1/20], Iteration [600/782], Loss: 1.3290
# Epoch [1/20], Iteration [700/782], Loss: 1.2941
# Epoch [1/20], Loss: 0.1332
# Test Loss: 1.2874
# Epoch [2/20], Iteration [100/782], Loss: 1.2702
# Epoch [2/20], Iteration [200/782], Loss: 1.1903
# Epoch [2/20], Iteration [300/782], Loss: 1.1627
# Epoch [2/20], Iteration [400/782], Loss: 1.1264
# Epoch [2/20], Iteration [500/782], Loss: 1.1272
# Epoch [2/20], Iteration [600/782], Loss: 1.1058
# Epoch [2/20], Iteration [700/782], Loss: 1.0855
# Epoch [2/20], Loss: 0.1104
# Test Loss: 1.0848
# Epoch [3/20], Iteration [100/782], Loss: 1.0493
# Epoch [3/20], Iteration [200/782], Loss: 1.0258
# Epoch [3/20], Iteration [300/782], Loss: 1.0304
# Epoch [3/20], Iteration [400/782], Loss: 1.0258
# Epoch [3/20], Iteration [500/782], Loss: 1.0040
# Epoch [3/20], Iteration [600/782], Loss: 0.9785
# Epoch [3/20], Iteration [700/782], Loss: 0.9915
# Epoch [3/20], Loss: 0.1021
# Test Loss: 0.9666
# Epoch [4/20], Iteration [100/782], Loss: 0.9722
# Epoch [4/20], Iteration [200/782], Loss: 0.9566
# Epoch [4/20], Iteration [300/782], Loss: 0.9424
# Epoch [4/20], Iteration [400/782], Loss: 0.9524
# Epoch [4/20], Iteration [500/782], Loss: 0.9299
# Epoch [4/20], Iteration [600/782], Loss: 0.9245
# Epoch [4/20], Iteration [700/782], Loss: 0.9103
# Epoch [4/20], Loss: 0.0962
# Test Loss: 0.9000
# Epoch [5/20], Iteration [100/782], Loss: 0.8818
# Epoch [5/20], Iteration [200/782], Loss: 0.9080
# Epoch [5/20], Iteration [300/782], Loss: 0.8805
# Epoch [5/20], Iteration [400/782], Loss: 0.8918
# Epoch [5/20], Iteration [500/782], Loss: 0.8990
# Epoch [5/20], Iteration [600/782], Loss: 0.8716
# Epoch [5/20], Iteration [700/782], Loss: 0.8870
# Epoch [5/20], Loss: 0.0894
# Test Loss: 0.9179
# Epoch [6/20], Iteration [100/782], Loss: 0.8240
# Epoch [6/20], Iteration [200/782], Loss: 0.8291
# Epoch [6/20], Iteration [300/782], Loss: 0.8462
# Epoch [6/20], Iteration [400/782], Loss: 0.8411
# Epoch [6/20], Iteration [500/782], Loss: 0.8774
# Epoch [6/20], Iteration [600/782], Loss: 0.8609
# Epoch [6/20], Iteration [700/782], Loss: 0.8438
# Epoch [6/20], Loss: 0.0870
# Test Loss: 0.8483
# Epoch [7/20], Iteration [100/782], Loss: 0.8160
# Epoch [7/20], Iteration [200/782], Loss: 0.8049
# Epoch [7/20], Iteration [300/782], Loss: 0.8050
# Epoch [7/20], Iteration [400/782], Loss: 0.8213
# Epoch [7/20], Iteration [500/782], Loss: 0.8081
# Epoch [7/20], Iteration [600/782], Loss: 0.8081
# Epoch [7/20], Iteration [700/782], Loss: 0.8010
# Epoch [7/20], Loss: 0.0835
# Test Loss: 0.8726
# Epoch [8/20], Iteration [100/782], Loss: 0.7955
# Epoch [8/20], Iteration [200/782], Loss: 0.8011
# Epoch [8/20], Iteration [300/782], Loss: 0.7722
# Epoch [8/20], Iteration [400/782], Loss: 0.7622
# Epoch [8/20], Iteration [500/782], Loss: 0.7665
# Epoch [8/20], Iteration [600/782], Loss: 0.7798
# Epoch [8/20], Iteration [700/782], Loss: 0.7773
# Epoch [8/20], Loss: 0.0804
# Test Loss: 0.8252
# Epoch [9/20], Iteration [100/782], Loss: 0.7574
# Epoch [9/20], Iteration [200/782], Loss: 0.7478
# Epoch [9/20], Iteration [300/782], Loss: 0.7901
# Epoch [9/20], Iteration [400/782], Loss: 0.7652
# Epoch [9/20], Iteration [500/782], Loss: 0.7530
# Epoch [9/20], Iteration [600/782], Loss: 0.7470
# Epoch [9/20], Iteration [700/782], Loss: 0.7526
# Epoch [9/20], Loss: 0.0783
# Test Loss: 0.7910
# Epoch [10/20], Iteration [100/782], Loss: 0.7398
# Epoch [10/20], Iteration [200/782], Loss: 0.7385
# Epoch [10/20], Iteration [300/782], Loss: 0.7244
# Epoch [10/20], Iteration [400/782], Loss: 0.7404
# Epoch [10/20], Iteration [500/782], Loss: 0.7707
# Epoch [10/20], Iteration [600/782], Loss: 0.7122
# Epoch [10/20], Iteration [700/782], Loss: 0.7373
# Epoch [10/20], Loss: 0.0771
# Test Loss: 0.8104
# Epoch [11/20], Iteration [100/782], Loss: 0.7104
# Epoch [11/20], Iteration [200/782], Loss: 0.7360
# Epoch [11/20], Iteration [300/782], Loss: 0.7223
# Epoch [11/20], Iteration [400/782], Loss: 0.7103
# Epoch [11/20], Iteration [500/782], Loss: 0.7159
# Epoch [11/20], Iteration [600/782], Loss: 0.7290
# Epoch [11/20], Iteration [700/782], Loss: 0.7276
# Epoch [11/20], Loss: 0.0758
# Test Loss: 0.7624
# Epoch [12/20], Iteration [100/782], Loss: 0.6887
# Epoch [12/20], Iteration [200/782], Loss: 0.7061
# Epoch [12/20], Iteration [300/782], Loss: 0.7262
# Epoch [12/20], Iteration [400/782], Loss: 0.6865
# Epoch [12/20], Iteration [500/782], Loss: 0.7224
# Epoch [12/20], Iteration [600/782], Loss: 0.6945
# Epoch [12/20], Iteration [700/782], Loss: 0.7169
# Epoch [12/20], Loss: 0.0725
# Test Loss: 0.7710
# Epoch [13/20], Iteration [100/782], Loss: 0.7018
# Epoch [13/20], Iteration [200/782], Loss: 0.6655
# Epoch [13/20], Iteration [300/782], Loss: 0.7073
# Epoch [13/20], Iteration [400/782], Loss: 0.6711
# Epoch [13/20], Iteration [500/782], Loss: 0.6966
# Epoch [13/20], Iteration [600/782], Loss: 0.6880
# Epoch [13/20], Iteration [700/782], Loss: 0.7026
# Epoch [13/20], Loss: 0.0747
# Test Loss: 0.7411
# Epoch [14/20], Iteration [100/782], Loss: 0.6701
# Epoch [14/20], Iteration [200/782], Loss: 0.6680
# Epoch [14/20], Iteration [300/782], Loss: 0.6675
# Epoch [14/20], Iteration [400/782], Loss: 0.6809
# Epoch [14/20], Iteration [500/782], Loss: 0.6944
# Epoch [14/20], Iteration [600/782], Loss: 0.6743
# Epoch [14/20], Iteration [700/782], Loss: 0.6749
# Epoch [14/20], Loss: 0.0717
# Test Loss: 0.7483
# Epoch [15/20], Iteration [100/782], Loss: 0.6557
# Epoch [15/20], Iteration [200/782], Loss: 0.6700
# Epoch [15/20], Iteration [300/782], Loss: 0.6478
# Epoch [15/20], Iteration [400/782], Loss: 0.6628
# Epoch [15/20], Iteration [500/782], Loss: 0.6695
# Epoch [15/20], Iteration [600/782], Loss: 0.6596
# Epoch [15/20], Iteration [700/782], Loss: 0.6734
# Epoch [15/20], Loss: 0.0662
# Test Loss: 0.7712
# Epoch [16/20], Iteration [100/782], Loss: 0.6596
# Epoch [16/20], Iteration [200/782], Loss: 0.6510
# Epoch [16/20], Iteration [300/782], Loss: 0.6399
# Epoch [16/20], Iteration [400/782], Loss: 0.6591
# Epoch [16/20], Iteration [500/782], Loss: 0.6543
# Epoch [16/20], Iteration [600/782], Loss: 0.6709
# Epoch [16/20], Iteration [700/782], Loss: 0.6443
# Epoch [16/20], Loss: 0.0692
# Test Loss: 0.7249
# Epoch [17/20], Iteration [100/782], Loss: 0.6235
# Epoch [17/20], Iteration [200/782], Loss: 0.6641
# Epoch [17/20], Iteration [300/782], Loss: 0.6399
# Epoch [17/20], Iteration [400/782], Loss: 0.6811
# Epoch [17/20], Iteration [500/782], Loss: 0.6489
# Epoch [17/20], Iteration [600/782], Loss: 0.6477
# Epoch [17/20], Iteration [700/782], Loss: 0.6564
# Epoch [17/20], Loss: 0.0665
# Test Loss: 0.7241
# Epoch [18/20], Iteration [100/782], Loss: 0.6254
# Epoch [18/20], Iteration [200/782], Loss: 0.6414
# Epoch [18/20], Iteration [300/782], Loss: 0.6160
# Epoch [18/20], Iteration [400/782], Loss: 0.6524
# Epoch [18/20], Iteration [500/782], Loss: 0.6487
# Epoch [18/20], Iteration [600/782], Loss: 0.6363
# Epoch [18/20], Iteration [700/782], Loss: 0.6477
# Epoch [18/20], Loss: 0.0679
# Test Loss: 0.7426
# Epoch [19/20], Iteration [100/782], Loss: 0.6300
# Epoch [19/20], Iteration [200/782], Loss: 0.6191
# Epoch [19/20], Iteration [300/782], Loss: 0.6352
# Epoch [19/20], Iteration [400/782], Loss: 0.6326
# Epoch [19/20], Iteration [500/782], Loss: 0.6225
# Epoch [19/20], Iteration [600/782], Loss: 0.6306
# Epoch [19/20], Iteration [700/782], Loss: 0.6381
# Epoch [19/20], Loss: 0.0644
# Test Loss: 0.7113
# Epoch [20/20], Iteration [100/782], Loss: 0.6151
# Epoch [20/20], Iteration [200/782], Loss: 0.6002
# Epoch [20/20], Iteration [300/782], Loss: 0.6228
# Epoch [20/20], Iteration [400/782], Loss: 0.6176
# Epoch [20/20], Iteration [500/782], Loss: 0.6145
# Epoch [20/20], Iteration [600/782], Loss: 0.5902
# Epoch [20/20], Iteration [700/782], Loss: 0.6185
# Epoch [20/20], Loss: 0.0658
# Test Loss: 0.7067
# Accuracy of the model on the 10,000 test images: 75.71%

# %%
plt.plot(losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
plt.plot(losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
