# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.nn import functional as F
from matplotlib import pyplot as plt
import numpy as np

# Set the random seed for reproducibility
torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Use GPU if available

# %%
# Define transformations for the training and test data
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

# Load the CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:12<00:00, 13344896.86it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
labels = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
std = [0.2023, 0.1994, 0.2010]
mean = [0.4914, 0.4822, 0.4465]
plt.imshow(((train_features[0].permute(1, 2, 0) * np.array(std) + np.array(mean))).numpy())
plt.show()
print(f"Label: {labels[train_labels[0]]}")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Feature batch shape: torch.Size([64, 3, 32, 32])
# Labels batch shape: torch.Size([64])
# Label: frog

# %%
def conv3x3(in_planes, out_planes, stride=1):
  """3x3 convolution with padding"""
  return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                   padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
  """1x1 convolution"""
  return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)

# %%
# Define the VGG16 model
class VGG16(nn.Module):
    def __init__(self):
        super(VGG16, self).__init__()
        self.features = nn.Sequential(
            # Conv Block 1
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv Block 2
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv Block 3
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        # Đảm bảo rằng đầu ra từ phần convolutional sẽ có kích thước (7x7x512)
        #self.avgpool = nn.AdaptiveAvgPool2d((7, 7))
        self.classifier = nn.Sequential(
            nn.Linear(256 * 4 * 4, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 10),
        )

    def forward(self, x):
        x = self.features(x)
        #x = self.avgpool(x)  # Đảm bảo đầu ra có kích thước 7x7x512
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def evaluate_model(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

    return test_loss / len(test_loader)

def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs):
    losses = []
    test_losses = []
    model.train()
    num_iter = 0
    for epoch in range(num_epochs):
        running_loss = 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            num_iter += 1
            if num_iter % 100 == 0:  # Print loss every 100 iterations
                print(f'Epoch [{epoch+1}/{num_epochs}], Iteration [{num_iter}/{len(train_loader)}], Loss: {running_loss/100:.4f}')
                running_loss = 0.0
        num_iter = 0
        losses.append(running_loss / len(train_loader))
        test_loss = evaluate_model(model, test_loader, criterion)
        test_losses.append(test_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}')
        print(f'Test Loss: {test_loss:.4f}')
    return losses, test_losses

# %%
# Initialize the model, loss function, and optimizer
model = VGG16()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training the model
num_epochs = 50
losses, test_losses = train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs)

# Evaluating the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the model on the 10,000 test images: {100 * correct / total:.2f}%')
# Out:
# Epoch [1/50], Iteration [100/782], Loss: 2.2535
# Epoch [1/50], Iteration [200/782], Loss: 2.0024
# Epoch [1/50], Iteration [300/782], Loss: 1.8874
# Epoch [1/50], Iteration [400/782], Loss: 1.7948
# Epoch [1/50], Iteration [500/782], Loss: 1.7506
# Epoch [1/50], Iteration [600/782], Loss: 1.6736
# Epoch [1/50], Iteration [700/782], Loss: 1.6312
# Epoch [1/50], Loss: 0.1681
# Test Loss: 1.5153
# Epoch [2/50], Iteration [100/782], Loss: 1.5073
# Epoch [2/50], Iteration [200/782], Loss: 1.4517
# Epoch [2/50], Iteration [300/782], Loss: 1.4360
# Epoch [2/50], Iteration [400/782], Loss: 1.3676
# Epoch [2/50], Iteration [500/782], Loss: 1.3358
# Epoch [2/50], Iteration [600/782], Loss: 1.2933
# Epoch [2/50], Iteration [700/782], Loss: 1.2922
# Epoch [2/50], Loss: 0.1326
# Test Loss: 1.2276
# Epoch [3/50], Iteration [100/782], Loss: 1.2404
# Epoch [3/50], Iteration [200/782], Loss: 1.2059
# Epoch [3/50], Iteration [300/782], Loss: 1.2009
# Epoch [3/50], Iteration [400/782], Loss: 1.1828
# Epoch [3/50], Iteration [500/782], Loss: 1.1486
# Epoch [3/50], Iteration [600/782], Loss: 1.1400
# Epoch [3/50], Iteration [700/782], Loss: 1.1047
# Epoch [3/50], Loss: 0.1152
# Test Loss: 1.1040
# Epoch [4/50], Iteration [100/782], Loss: 1.0546
# Epoch [4/50], Iteration [200/782], Loss: 1.0768
# Epoch [4/50], Iteration [300/782], Loss: 1.0404
# Epoch [4/50], Iteration [400/782], Loss: 1.0372
# Epoch [4/50], Iteration [500/782], Loss: 1.0453
# Epoch [4/50], Iteration [600/782], Loss: 1.0201
# Epoch [4/50], Iteration [700/782], Loss: 1.0237
# Epoch [4/50], Loss: 0.1042
# Test Loss: 1.0005
# Epoch [5/50], Iteration [100/782], Loss: 0.9672
# Epoch [5/50], Iteration [200/782], Loss: 0.9806
# Epoch [5/50], Iteration [300/782], Loss: 0.9649
# Epoch [5/50], Iteration [400/782], Loss: 0.9713
# Epoch [5/50], Iteration [500/782], Loss: 0.9390
# Epoch [5/50], Iteration [600/782], Loss: 0.9298
# Epoch [5/50], Iteration [700/782], Loss: 0.9251
# Epoch [5/50], Loss: 0.0992
# Test Loss: 0.9184
# Epoch [6/50], Iteration [100/782], Loss: 0.9218
# Epoch [6/50], Iteration [200/782], Loss: 0.8696
# Epoch [6/50], Iteration [300/782], Loss: 0.8940
# Epoch [6/50], Iteration [400/782], Loss: 0.8811
# Epoch [6/50], Iteration [500/782], Loss: 0.8872
# Epoch [6/50], Iteration [600/782], Loss: 0.8854
# Epoch [6/50], Iteration [700/782], Loss: 0.8667
# Epoch [6/50], Loss: 0.0901
# Test Loss: 0.9417
# Epoch [7/50], Iteration [100/782], Loss: 0.8470
# Epoch [7/50], Iteration [200/782], Loss: 0.8228
# Epoch [7/50], Iteration [300/782], Loss: 0.8427
# Epoch [7/50], Iteration [400/782], Loss: 0.8343
# Epoch [7/50], Iteration [500/782], Loss: 0.8071
# Epoch [7/50], Iteration [600/782], Loss: 0.8402
# Epoch [7/50], Iteration [700/782], Loss: 0.8192
# Epoch [7/50], Loss: 0.0864
# Test Loss: 0.8136
# Epoch [8/50], Iteration [100/782], Loss: 0.7932
# Epoch [8/50], Iteration [200/782], Loss: 0.8027
# Epoch [8/50], Iteration [300/782], Loss: 0.7746
# Epoch [8/50], Iteration [400/782], Loss: 0.7954
# Epoch [8/50], Iteration [500/782], Loss: 0.7832
# Epoch [8/50], Iteration [600/782], Loss: 0.7539
# Epoch [8/50], Iteration [700/782], Loss: 0.7861
# Epoch [8/50], Loss: 0.0817
# Test Loss: 0.8064
# Epoch [9/50], Iteration [100/782], Loss: 0.7378
# Epoch [9/50], Iteration [200/782], Loss: 0.7588
# Epoch [9/50], Iteration [300/782], Loss: 0.7458
# Epoch [9/50], Iteration [400/782], Loss: 0.7483
# Epoch [9/50], Iteration [500/782], Loss: 0.7624
# Epoch [9/50], Iteration [600/782], Loss: 0.7680
# Epoch [9/50], Iteration [700/782], Loss: 0.7455
# Epoch [9/50], Loss: 0.0788
# Test Loss: 0.7665
# Epoch [10/50], Iteration [100/782], Loss: 0.7269
# Epoch [10/50], Iteration [200/782], Loss: 0.7358
# Epoch [10/50], Iteration [300/782], Loss: 0.7242
# Epoch [10/50], Iteration [400/782], Loss: 0.7154
# Epoch [10/50], Iteration [500/782], Loss: 0.7283
# Epoch [10/50], Iteration [600/782], Loss: 0.7199
# Epoch [10/50], Iteration [700/782], Loss: 0.7320
# Epoch [10/50], Loss: 0.0724
# Test Loss: 0.7912
# Epoch [11/50], Iteration [100/782], Loss: 0.6799
# Epoch [11/50], Iteration [200/782], Loss: 0.6912
# Epoch [11/50], Iteration [300/782], Loss: 0.6904
# Epoch [11/50], Iteration [400/782], Loss: 0.6918
# Epoch [11/50], Iteration [500/782], Loss: 0.6761
# Epoch [11/50], Iteration [600/782], Loss: 0.6837
# Epoch [11/50], Iteration [700/782], Loss: 0.7136
# Epoch [11/50], Loss: 0.0738
# Test Loss: 0.7713
# Epoch [12/50], Iteration [100/782], Loss: 0.6590
# Epoch [12/50], Iteration [200/782], Loss: 0.6816
# Epoch [12/50], Iteration [300/782], Loss: 0.6694
# Epoch [12/50], Iteration [400/782], Loss: 0.6422
# Epoch [12/50], Iteration [500/782], Loss: 0.6817
# Epoch [12/50], Iteration [600/782], Loss: 0.6878
# Epoch [12/50], Iteration [700/782], Loss: 0.6616
# Epoch [12/50], Loss: 0.0696
# Test Loss: 0.7438
# Epoch [13/50], Iteration [100/782], Loss: 0.6556
# Epoch [13/50], Iteration [200/782], Loss: 0.6466
# Epoch [13/50], Iteration [300/782], Loss: 0.6304
# Epoch [13/50], Iteration [400/782], Loss: 0.6318
# Epoch [13/50], Iteration [500/782], Loss: 0.6662
# Epoch [13/50], Iteration [600/782], Loss: 0.6457
# Epoch [13/50], Iteration [700/782], Loss: 0.6601
# Epoch [13/50], Loss: 0.0682
# Test Loss: 0.7332
# Epoch [14/50], Iteration [100/782], Loss: 0.6369
# Epoch [14/50], Iteration [200/782], Loss: 0.6136
# Epoch [14/50], Iteration [300/782], Loss: 0.6402
# Epoch [14/50], Iteration [400/782], Loss: 0.6513
# Epoch [14/50], Iteration [500/782], Loss: 0.6572
# Epoch [14/50], Iteration [600/782], Loss: 0.6037
# Epoch [14/50], Iteration [700/782], Loss: 0.6390
# Epoch [14/50], Loss: 0.0692
# Test Loss: 0.6778
# Epoch [15/50], Iteration [100/782], Loss: 0.6147
# Epoch [15/50], Iteration [200/782], Loss: 0.6241
# Epoch [15/50], Iteration [300/782], Loss: 0.6340
# Epoch [15/50], Iteration [400/782], Loss: 0.6048
# Epoch [15/50], Iteration [500/782], Loss: 0.6100
# Epoch [15/50], Iteration [600/782], Loss: 0.6218
# Epoch [15/50], Iteration [700/782], Loss: 0.6252
# Epoch [15/50], Loss: 0.0668
# Test Loss: 0.7084
# Epoch [16/50], Iteration [100/782], Loss: 0.5829
# Epoch [16/50], Iteration [200/782], Loss: 0.6148
# Epoch [16/50], Iteration [300/782], Loss: 0.6304
# Epoch [16/50], Iteration [400/782], Loss: 0.5761
# Epoch [16/50], Iteration [500/782], Loss: 0.6071
# Epoch [16/50], Iteration [600/782], Loss: 0.5958
# Epoch [16/50], Iteration [700/782], Loss: 0.6158
# Epoch [16/50], Loss: 0.0637
# Test Loss: 0.6687
# Epoch [17/50], Iteration [100/782], Loss: 0.6023
# Epoch [17/50], Iteration [200/782], Loss: 0.5944
# Epoch [17/50], Iteration [300/782], Loss: 0.5814
# Epoch [17/50], Iteration [400/782], Loss: 0.6142
# Epoch [17/50], Iteration [500/782], Loss: 0.6000
# Epoch [17/50], Iteration [600/782], Loss: 0.5744
# Epoch [17/50], Iteration [700/782], Loss: 0.5850
# Epoch [17/50], Loss: 0.0621
# Test Loss: 0.6778
# Epoch [18/50], Iteration [100/782], Loss: 0.5903
# Epoch [18/50], Iteration [200/782], Loss: 0.5974
# Epoch [18/50], Iteration [300/782], Loss: 0.5744
# Epoch [18/50], Iteration [400/782], Loss: 0.5620
# Epoch [18/50], Iteration [500/782], Loss: 0.5658
# Epoch [18/50], Iteration [600/782], Loss: 0.5770
# Epoch [18/50], Iteration [700/782], Loss: 0.5894
# Epoch [18/50], Loss: 0.0628
# Test Loss: 0.6896
# Epoch [19/50], Iteration [100/782], Loss: 0.5743
# Epoch [19/50], Iteration [200/782], Loss: 0.5835
# Epoch [19/50], Iteration [300/782], Loss: 0.5910
# Epoch [19/50], Iteration [400/782], Loss: 0.5735
# Epoch [19/50], Iteration [500/782], Loss: 0.5742
# Epoch [19/50], Iteration [600/782], Loss: 0.5897
# Epoch [19/50], Iteration [700/782], Loss: 0.5845
# Epoch [19/50], Loss: 0.0575
# Test Loss: 0.6698
# Epoch [20/50], Iteration [100/782], Loss: 0.5586
# Epoch [20/50], Iteration [200/782], Loss: 0.5549
# Epoch [20/50], Iteration [300/782], Loss: 0.5815
# Epoch [20/50], Iteration [400/782], Loss: 0.5340
# Epoch [20/50], Iteration [500/782], Loss: 0.5667
# Epoch [20/50], Iteration [600/782], Loss: 0.5972
# Epoch [20/50], Iteration [700/782], Loss: 0.5584
# Epoch [20/50], Loss: 0.0589
# Test Loss: 0.6309
# Epoch [21/50], Iteration [100/782], Loss: 0.5356
# Epoch [21/50], Iteration [200/782], Loss: 0.5487
# Epoch [21/50], Iteration [300/782], Loss: 0.5615
# Epoch [21/50], Iteration [400/782], Loss: 0.5688
# Epoch [21/50], Iteration [500/782], Loss: 0.5391
# Epoch [21/50], Iteration [600/782], Loss: 0.5477
# Epoch [21/50], Iteration [700/782], Loss: 0.5738
# Epoch [21/50], Loss: 0.0574
# Test Loss: 0.6304
# Epoch [22/50], Iteration [100/782], Loss: 0.5258
# Epoch [22/50], Iteration [200/782], Loss: 0.5477
# Epoch [22/50], Iteration [300/782], Loss: 0.5545
# Epoch [22/50], Iteration [400/782], Loss: 0.5568
# Epoch [22/50], Iteration [500/782], Loss: 0.5409
# Epoch [22/50], Iteration [600/782], Loss: 0.5215
# Epoch [22/50], Iteration [700/782], Loss: 0.5632
# Epoch [22/50], Loss: 0.0603
# Test Loss: 0.6506
# Epoch [23/50], Iteration [100/782], Loss: 0.5161
# Epoch [23/50], Iteration [200/782], Loss: 0.5302
# Epoch [23/50], Iteration [300/782], Loss: 0.5182
# Epoch [23/50], Iteration [400/782], Loss: 0.5316
# Epoch [23/50], Iteration [500/782], Loss: 0.5330
# Epoch [23/50], Iteration [600/782], Loss: 0.5309
# Epoch [23/50], Iteration [700/782], Loss: 0.5416
# Epoch [23/50], Loss: 0.0591
# Test Loss: 0.6346
# Epoch [24/50], Iteration [100/782], Loss: 0.5400
# Epoch [24/50], Iteration [200/782], Loss: 0.5322
# Epoch [24/50], Iteration [300/782], Loss: 0.5359
# Epoch [24/50], Iteration [400/782], Loss: 0.5349
# Epoch [24/50], Iteration [500/782], Loss: 0.5420
# Epoch [24/50], Iteration [600/782], Loss: 0.5383
# Epoch [24/50], Iteration [700/782], Loss: 0.5377
# Epoch [24/50], Loss: 0.0558
# Test Loss: 0.6475
# Epoch [25/50], Iteration [100/782], Loss: 0.5117
# Epoch [25/50], Iteration [200/782], Loss: 0.5205
# Epoch [25/50], Iteration [300/782], Loss: 0.5112
# Epoch [25/50], Iteration [400/782], Loss: 0.5153
# Epoch [25/50], Iteration [500/782], Loss: 0.5320
# Epoch [25/50], Iteration [600/782], Loss: 0.4975
# Epoch [25/50], Iteration [700/782], Loss: 0.5399
# Epoch [25/50], Loss: 0.0557
# Test Loss: 0.6637
# Epoch [26/50], Iteration [100/782], Loss: 0.5016
# Epoch [26/50], Iteration [200/782], Loss: 0.4922
# Epoch [26/50], Iteration [300/782], Loss: 0.5150
# Epoch [26/50], Iteration [400/782], Loss: 0.5263
# Epoch [26/50], Iteration [500/782], Loss: 0.5155
# Epoch [26/50], Iteration [600/782], Loss: 0.5281
# Epoch [26/50], Iteration [700/782], Loss: 0.5241
# Epoch [26/50], Loss: 0.0545
# Test Loss: 0.6488
# Epoch [27/50], Iteration [100/782], Loss: 0.4981
# Epoch [27/50], Iteration [200/782], Loss: 0.5033
# Epoch [27/50], Iteration [300/782], Loss: 0.4807
# Epoch [27/50], Iteration [400/782], Loss: 0.4795
# Epoch [27/50], Iteration [500/782], Loss: 0.5237
# Epoch [27/50], Iteration [600/782], Loss: 0.5034
# Epoch [27/50], Iteration [700/782], Loss: 0.5080
# Epoch [27/50], Loss: 0.0560
# Test Loss: 0.6878
# Epoch [28/50], Iteration [100/782], Loss: 0.4973
# Epoch [28/50], Iteration [200/782], Loss: 0.4839
# Epoch [28/50], Iteration [300/782], Loss: 0.5228
# Epoch [28/50], Iteration [400/782], Loss: 0.4869
# Epoch [28/50], Iteration [500/782], Loss: 0.5097
# Epoch [28/50], Iteration [600/782], Loss: 0.4981
# Epoch [28/50], Iteration [700/782], Loss: 0.4865
# Epoch [28/50], Loss: 0.0544
# Test Loss: 0.6332
# Epoch [29/50], Iteration [100/782], Loss: 0.5015
# Epoch [29/50], Iteration [200/782], Loss: 0.4754
# Epoch [29/50], Iteration [300/782], Loss: 0.4928
# Epoch [29/50], Iteration [400/782], Loss: 0.4844
# Epoch [29/50], Iteration [500/782], Loss: 0.4957
# Epoch [29/50], Iteration [600/782], Loss: 0.4930
# Epoch [29/50], Iteration [700/782], Loss: 0.5103
# Epoch [29/50], Loss: 0.0543
# Test Loss: 0.6117
# Epoch [30/50], Iteration [100/782], Loss: 0.4729
# Epoch [30/50], Iteration [200/782], Loss: 0.4892
# Epoch [30/50], Iteration [300/782], Loss: 0.4586
# Epoch [30/50], Iteration [400/782], Loss: 0.4869
# Epoch [30/50], Iteration [500/782], Loss: 0.4933
# Epoch [30/50], Iteration [600/782], Loss: 0.4855
# Epoch [30/50], Iteration [700/782], Loss: 0.5155
# Epoch [30/50], Loss: 0.0505
# Test Loss: 0.6528
# Epoch [31/50], Iteration [100/782], Loss: 0.4746
# Epoch [31/50], Iteration [200/782], Loss: 0.5006
# Epoch [31/50], Iteration [300/782], Loss: 0.4885
# Epoch [31/50], Iteration [400/782], Loss: 0.4905
# Epoch [31/50], Iteration [500/782], Loss: 0.4889
# Epoch [31/50], Iteration [600/782], Loss: 0.4773
# Epoch [31/50], Iteration [700/782], Loss: 0.4752
# Epoch [31/50], Loss: 0.0527
# Test Loss: 0.6676
# Epoch [32/50], Iteration [100/782], Loss: 0.4920
# Epoch [32/50], Iteration [200/782], Loss: 0.4760
# Epoch [32/50], Iteration [300/782], Loss: 0.4718
# Epoch [32/50], Iteration [400/782], Loss: 0.4866
# Epoch [32/50], Iteration [500/782], Loss: 0.4662
# Epoch [32/50], Iteration [600/782], Loss: 0.4893
# Epoch [32/50], Iteration [700/782], Loss: 0.4990
# Epoch [32/50], Loss: 0.0491
# Test Loss: 0.6445
# Epoch [33/50], Iteration [100/782], Loss: 0.4565
# Epoch [33/50], Iteration [200/782], Loss: 0.4809
# Epoch [33/50], Iteration [300/782], Loss: 0.4676
# Epoch [33/50], Iteration [400/782], Loss: 0.4799
# Epoch [33/50], Iteration [500/782], Loss: 0.4770
# Epoch [33/50], Iteration [600/782], Loss: 0.4810
# Epoch [33/50], Iteration [700/782], Loss: 0.4785
# Epoch [33/50], Loss: 0.0485
# Test Loss: 0.6210
# Epoch [34/50], Iteration [100/782], Loss: 0.4499
# Epoch [34/50], Iteration [200/782], Loss: 0.4691
# Epoch [34/50], Iteration [300/782], Loss: 0.4494
# Epoch [34/50], Iteration [400/782], Loss: 0.4625
# Epoch [34/50], Iteration [500/782], Loss: 0.4730
# Epoch [34/50], Iteration [600/782], Loss: 0.4665
# Epoch [34/50], Iteration [700/782], Loss: 0.4940
# Epoch [34/50], Loss: 0.0510
# Test Loss: 0.6093
# Epoch [35/50], Iteration [100/782], Loss: 0.4756
# Epoch [35/50], Iteration [200/782], Loss: 0.4528
# Epoch [35/50], Iteration [300/782], Loss: 0.4724
# Epoch [35/50], Iteration [400/782], Loss: 0.4665
# Epoch [35/50], Iteration [500/782], Loss: 0.4550
# Epoch [35/50], Iteration [600/782], Loss: 0.4559
# Epoch [35/50], Iteration [700/782], Loss: 0.4873
# Epoch [35/50], Loss: 0.0480
# Test Loss: 0.6410
# Epoch [36/50], Iteration [100/782], Loss: 0.4494
# Epoch [36/50], Iteration [200/782], Loss: 0.4526
# Epoch [36/50], Iteration [300/782], Loss: 0.4579
# Epoch [36/50], Iteration [400/782], Loss: 0.4689
# Epoch [36/50], Iteration [500/782], Loss: 0.4515
# Epoch [36/50], Iteration [600/782], Loss: 0.4588
# Epoch [36/50], Iteration [700/782], Loss: 0.4626
# Epoch [36/50], Loss: 0.0487
# Test Loss: 0.6298
# Epoch [37/50], Iteration [100/782], Loss: 0.4403
# Epoch [37/50], Iteration [200/782], Loss: 0.4442
# Epoch [37/50], Iteration [300/782], Loss: 0.4513
# Epoch [37/50], Iteration [400/782], Loss: 0.4404
# Epoch [37/50], Iteration [500/782], Loss: 0.4569
# Epoch [37/50], Iteration [600/782], Loss: 0.4511
# Epoch [37/50], Iteration [700/782], Loss: 0.4585
# Epoch [37/50], Loss: 0.0495
# Test Loss: 0.5875
# Epoch [38/50], Iteration [100/782], Loss: 0.4649
# Epoch [38/50], Iteration [200/782], Loss: 0.4304
# Epoch [38/50], Iteration [300/782], Loss: 0.4682
# Epoch [38/50], Iteration [400/782], Loss: 0.4267
# Epoch [38/50], Iteration [500/782], Loss: 0.4477
# Epoch [38/50], Iteration [600/782], Loss: 0.4579
# Epoch [38/50], Iteration [700/782], Loss: 0.4630
# Epoch [38/50], Loss: 0.0469
# Test Loss: 0.5833
# Epoch [39/50], Iteration [100/782], Loss: 0.4383
# Epoch [39/50], Iteration [200/782], Loss: 0.4564
# Epoch [39/50], Iteration [300/782], Loss: 0.4369
# Epoch [39/50], Iteration [400/782], Loss: 0.4411
# Epoch [39/50], Iteration [500/782], Loss: 0.4625
# Epoch [39/50], Iteration [600/782], Loss: 0.4530
# Epoch [39/50], Iteration [700/782], Loss: 0.4313
# Epoch [39/50], Loss: 0.0487
# Test Loss: 0.6043
# Epoch [40/50], Iteration [100/782], Loss: 0.4370
# Epoch [40/50], Iteration [200/782], Loss: 0.4241
# Epoch [40/50], Iteration [300/782], Loss: 0.4438
# Epoch [40/50], Iteration [400/782], Loss: 0.4400
# Epoch [40/50], Iteration [500/782], Loss: 0.4644
# Epoch [40/50], Iteration [600/782], Loss: 0.4463
# Epoch [40/50], Iteration [700/782], Loss: 0.4488
# Epoch [40/50], Loss: 0.0484
# Test Loss: 0.5911
# Epoch [41/50], Iteration [100/782], Loss: 0.4167
# Epoch [41/50], Iteration [200/782], Loss: 0.4308
# Epoch [41/50], Iteration [300/782], Loss: 0.4357
# Epoch [41/50], Iteration [400/782], Loss: 0.4321
# Epoch [41/50], Iteration [500/782], Loss: 0.4397
# Epoch [41/50], Iteration [600/782], Loss: 0.4356
# Epoch [41/50], Iteration [700/782], Loss: 0.4492
# Epoch [41/50], Loss: 0.0445
# Test Loss: 0.6248
# Epoch [42/50], Iteration [100/782], Loss: 0.4210
# Epoch [42/50], Iteration [200/782], Loss: 0.4253
# Epoch [42/50], Iteration [300/782], Loss: 0.4277
# Epoch [42/50], Iteration [400/782], Loss: 0.4193
# Epoch [42/50], Iteration [500/782], Loss: 0.4491
# Epoch [42/50], Iteration [600/782], Loss: 0.4210
# Epoch [42/50], Iteration [700/782], Loss: 0.4432
# Epoch [42/50], Loss: 0.0459
# Test Loss: 0.5789
# Epoch [43/50], Iteration [100/782], Loss: 0.4153
# Epoch [43/50], Iteration [200/782], Loss: 0.4501
# Epoch [43/50], Iteration [300/782], Loss: 0.4312
# Epoch [43/50], Iteration [400/782], Loss: 0.4372
# Epoch [43/50], Iteration [500/782], Loss: 0.4506
# Epoch [43/50], Iteration [600/782], Loss: 0.4213
# Epoch [43/50], Iteration [700/782], Loss: 0.4304
# Epoch [43/50], Loss: 0.0477
# Test Loss: 0.6002
# Epoch [44/50], Iteration [100/782], Loss: 0.4251
# Epoch [44/50], Iteration [200/782], Loss: 0.4207
# Epoch [44/50], Iteration [300/782], Loss: 0.4429
# Epoch [44/50], Iteration [400/782], Loss: 0.4071
# Epoch [44/50], Iteration [500/782], Loss: 0.4457
# Epoch [44/50], Iteration [600/782], Loss: 0.4359
# Epoch [44/50], Iteration [700/782], Loss: 0.4330
# Epoch [44/50], Loss: 0.0462
# Test Loss: 0.6317
# Epoch [45/50], Iteration [100/782], Loss: 0.4069
# Epoch [45/50], Iteration [200/782], Loss: 0.3971
# Epoch [45/50], Iteration [300/782], Loss: 0.4042
# Epoch [45/50], Iteration [400/782], Loss: 0.4397
# Epoch [45/50], Iteration [500/782], Loss: 0.4232
# Epoch [45/50], Iteration [600/782], Loss: 0.4438
# Epoch [45/50], Iteration [700/782], Loss: 0.4707
# Epoch [45/50], Loss: 0.0460
# Test Loss: 0.6150
# Epoch [46/50], Iteration [100/782], Loss: 0.4321
# Epoch [46/50], Iteration [200/782], Loss: 0.4138
# Epoch [46/50], Iteration [300/782], Loss: 0.4346
# Epoch [46/50], Iteration [400/782], Loss: 0.3790
# Epoch [46/50], Iteration [500/782], Loss: 0.4341
# Epoch [46/50], Iteration [600/782], Loss: 0.4242
# Epoch [46/50], Iteration [700/782], Loss: 0.4089
# Epoch [46/50], Loss: 0.0433
# Test Loss: 0.6004
# Epoch [47/50], Iteration [100/782], Loss: 0.4164
# Epoch [47/50], Iteration [200/782], Loss: 0.4042
# Epoch [47/50], Iteration [300/782], Loss: 0.4023
# Epoch [47/50], Iteration [400/782], Loss: 0.4125
# Epoch [47/50], Iteration [500/782], Loss: 0.4509
# Epoch [47/50], Iteration [600/782], Loss: 0.3990
# Epoch [47/50], Iteration [700/782], Loss: 0.4265
# Epoch [47/50], Loss: 0.0434
# Test Loss: 0.5665
# Epoch [48/50], Iteration [100/782], Loss: 0.3667
# Epoch [48/50], Iteration [200/782], Loss: 0.3949
# Epoch [48/50], Iteration [300/782], Loss: 0.3969
# Epoch [48/50], Iteration [400/782], Loss: 0.4073
# Epoch [48/50], Iteration [500/782], Loss: 0.4277
# Epoch [48/50], Iteration [600/782], Loss: 0.4170
# Epoch [48/50], Iteration [700/782], Loss: 0.4320
# Epoch [48/50], Loss: 0.0462
# Test Loss: 0.5805
# Epoch [49/50], Iteration [100/782], Loss: 0.4172
# Epoch [49/50], Iteration [200/782], Loss: 0.3996
# Epoch [49/50], Iteration [300/782], Loss: 0.4184
# Epoch [49/50], Iteration [400/782], Loss: 0.4038
# Epoch [49/50], Iteration [500/782], Loss: 0.4308
# Epoch [49/50], Iteration [600/782], Loss: 0.4118
# Epoch [49/50], Iteration [700/782], Loss: 0.4101
# Epoch [49/50], Loss: 0.0434
# Test Loss: 0.5861
# Epoch [50/50], Iteration [100/782], Loss: 0.4015
# Epoch [50/50], Iteration [200/782], Loss: 0.3915
# Epoch [50/50], Iteration [300/782], Loss: 0.4062
# Epoch [50/50], Iteration [400/782], Loss: 0.3970
# Epoch [50/50], Iteration [500/782], Loss: 0.4170
# Epoch [50/50], Iteration [600/782], Loss: 0.4051
# Epoch [50/50], Iteration [700/782], Loss: 0.4188
# Epoch [50/50], Loss: 0.0453
# Test Loss: 0.5709
# Accuracy of the model on the 10,000 test images: 81.61%

# %%
plt.plot(losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
