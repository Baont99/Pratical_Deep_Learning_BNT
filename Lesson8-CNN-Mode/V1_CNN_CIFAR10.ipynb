# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.nn import functional as F
from matplotlib import pyplot as plt
import numpy as np

# Set the random seed for reproducibility
torch.manual_seed(42)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Use GPU if available

# %%
# Define transformations for the training and test data
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
])

# Load the CIFAR-10 dataset
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# Data loaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:04<00:00, 34216670.13it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
labels = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]
train_features, train_labels = next(iter(train_loader))
print(f"Feature batch shape: {train_features.size()}")
print(f"Labels batch shape: {train_labels.size()}")
std = [0.2023, 0.1994, 0.2010]
mean = [0.4914, 0.4822, 0.4465]
plt.imshow(((train_features[0].permute(1, 2, 0) * np.array(std) + np.array(mean))).numpy())
plt.show()
print(f"Label: {labels[train_labels[0]]}")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Feature batch shape: torch.Size([64, 3, 32, 32])
# Labels batch shape: torch.Size([64])
# Label: frog

# %%
def conv3x3(in_planes, out_planes, stride=1):
  """3x3 convolution with padding"""
  return nn.Conv2d(in_planes, out_planes, kernel_size=3, stride=stride,
                   padding=1, bias=False)


def conv1x1(in_planes, out_planes, stride=1):
  """1x1 convolution"""
  return nn.Conv2d(in_planes, out_planes, kernel_size=1, stride=stride, bias=False)

# %%
# Define the model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.batch_norm1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.batch_norm2 = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 8 * 8, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.batch_norm1(self.conv1(x))))
        x = self.pool(F.relu(self.batch_norm2(self.conv2(x))))
        x = x.view(-1, 64 * 8 * 8)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %%
def evaluate_model(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()

    return test_loss / len(test_loader)

def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs):
    losses = []
    test_losses = []
    model.train()
    num_iter = 0
    for epoch in range(num_epochs):
        running_loss = 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            num_iter += 1
            if num_iter % 100 == 0:  # Print loss every 100 iterations
                print(f'Epoch [{epoch+1}/{num_epochs}], Iteration [{num_iter}/{len(train_loader)}], Loss: {running_loss/100:.4f}')
                running_loss = 0.0
        num_iter = 0
        losses.append(running_loss / len(train_loader))
        test_loss = evaluate_model(model, test_loader, criterion)
        test_losses.append(test_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}')
        print(f'Test Loss: {test_loss:.4f}')
    return losses, test_losses

# %%
# Initialize the model, loss function, and optimizer
model = CNN()
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.005)

# %%
# Training the model
num_epochs = 50
losses, test_losses = train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs)

# Evaluating the model
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the model on the 10,000 test images: {100 * correct / total:.2f}%')
# Out:
# Epoch [1/50], Iteration [100/782], Loss: 3.0412
# Epoch [1/50], Iteration [200/782], Loss: 2.0879
# Epoch [1/50], Iteration [300/782], Loss: 1.9887
# Epoch [1/50], Iteration [400/782], Loss: 1.8784
# Epoch [1/50], Iteration [500/782], Loss: 1.8329
# Epoch [1/50], Iteration [600/782], Loss: 1.8307
# Epoch [1/50], Iteration [700/782], Loss: 1.8113
# Epoch [1/50], Loss: 0.1852
# Test Loss: 1.8078
# Epoch [2/50], Iteration [100/782], Loss: 1.7948
# Epoch [2/50], Iteration [200/782], Loss: 1.7293
# Epoch [2/50], Iteration [300/782], Loss: 1.7291
# Epoch [2/50], Iteration [400/782], Loss: 1.6990
# Epoch [2/50], Iteration [500/782], Loss: 1.6812
# Epoch [2/50], Iteration [600/782], Loss: 1.6733
# Epoch [2/50], Iteration [700/782], Loss: 1.6772
# Epoch [2/50], Loss: 0.1764
# Test Loss: 1.6969
# Epoch [3/50], Iteration [100/782], Loss: 1.6456
# Epoch [3/50], Iteration [200/782], Loss: 1.6537
# Epoch [3/50], Iteration [300/782], Loss: 1.6320
# Epoch [3/50], Iteration [400/782], Loss: 1.6344
# Epoch [3/50], Iteration [500/782], Loss: 1.6204
# Epoch [3/50], Iteration [600/782], Loss: 1.6179
# Epoch [3/50], Iteration [700/782], Loss: 1.6279
# Epoch [3/50], Loss: 0.1679
# Test Loss: 1.5840
# Epoch [4/50], Iteration [100/782], Loss: 1.5924
# Epoch [4/50], Iteration [200/782], Loss: 1.5854
# Epoch [4/50], Iteration [300/782], Loss: 1.5863
# Epoch [4/50], Iteration [400/782], Loss: 1.6019
# Epoch [4/50], Iteration [500/782], Loss: 1.5888
# Epoch [4/50], Iteration [600/782], Loss: 1.5961
# Epoch [4/50], Iteration [700/782], Loss: 1.5722
# Epoch [4/50], Loss: 0.1596
# Test Loss: 1.4844
# Epoch [5/50], Iteration [100/782], Loss: 1.4653
# Epoch [5/50], Iteration [200/782], Loss: 1.4528
# Epoch [5/50], Iteration [300/782], Loss: 1.4602
# Epoch [5/50], Iteration [400/782], Loss: 1.4390
# Epoch [5/50], Iteration [500/782], Loss: 1.4211
# Epoch [5/50], Iteration [600/782], Loss: 1.4204
# Epoch [5/50], Iteration [700/782], Loss: 1.3678
# Epoch [5/50], Loss: 0.1457
# Test Loss: 1.4300
# Epoch [6/50], Iteration [100/782], Loss: 1.3948
# Epoch [6/50], Iteration [200/782], Loss: 1.3612
# Epoch [6/50], Iteration [300/782], Loss: 1.3465
# Epoch [6/50], Iteration [400/782], Loss: 1.3603
# Epoch [6/50], Iteration [500/782], Loss: 1.3680
# Epoch [6/50], Iteration [600/782], Loss: 1.3292
# Epoch [6/50], Iteration [700/782], Loss: 1.3346
# Epoch [6/50], Loss: 0.1395
# Test Loss: 1.3183
# Epoch [7/50], Iteration [100/782], Loss: 1.3164
# Epoch [7/50], Iteration [200/782], Loss: 1.3108
# Epoch [7/50], Iteration [300/782], Loss: 1.3037
# Epoch [7/50], Iteration [400/782], Loss: 1.2820
# Epoch [7/50], Iteration [500/782], Loss: 1.2816
# Epoch [7/50], Iteration [600/782], Loss: 1.3002
# Epoch [7/50], Iteration [700/782], Loss: 1.3120
# Epoch [7/50], Loss: 0.1336
# Test Loss: 1.2740
# Epoch [8/50], Iteration [100/782], Loss: 1.2652
# Epoch [8/50], Iteration [200/782], Loss: 1.2765
# Epoch [8/50], Iteration [300/782], Loss: 1.2489
# Epoch [8/50], Iteration [400/782], Loss: 1.2560
# Epoch [8/50], Iteration [500/782], Loss: 1.2709
# Epoch [8/50], Iteration [600/782], Loss: 1.2291
# Epoch [8/50], Iteration [700/782], Loss: 1.2229
# Epoch [8/50], Loss: 0.1308
# Test Loss: 1.2470
# Epoch [9/50], Iteration [100/782], Loss: 1.2049
# Epoch [9/50], Iteration [200/782], Loss: 1.2259
# Epoch [9/50], Iteration [300/782], Loss: 1.2138
# Epoch [9/50], Iteration [400/782], Loss: 1.2290
# Epoch [9/50], Iteration [500/782], Loss: 1.2152
# Epoch [9/50], Iteration [600/782], Loss: 1.2191
# Epoch [9/50], Iteration [700/782], Loss: 1.1936
# Epoch [9/50], Loss: 0.1301
# Test Loss: 1.2146
# Epoch [10/50], Iteration [100/782], Loss: 1.2043
# Epoch [10/50], Iteration [200/782], Loss: 1.2027
# Epoch [10/50], Iteration [300/782], Loss: 1.2112
# Epoch [10/50], Iteration [400/782], Loss: 1.1928
# Epoch [10/50], Iteration [500/782], Loss: 1.1881
# Epoch [10/50], Iteration [600/782], Loss: 1.1912
# Epoch [10/50], Iteration [700/782], Loss: 1.1836
# Epoch [10/50], Loss: 0.1251
# Test Loss: 1.2126
# Epoch [11/50], Iteration [100/782], Loss: 1.2021
# Epoch [11/50], Iteration [200/782], Loss: 1.1810
# Epoch [11/50], Iteration [300/782], Loss: 1.1659
# Epoch [11/50], Iteration [400/782], Loss: 1.1834
# Epoch [11/50], Iteration [500/782], Loss: 1.1576
# Epoch [11/50], Iteration [600/782], Loss: 1.1522
# Epoch [11/50], Iteration [700/782], Loss: 1.1592
# Epoch [11/50], Loss: 0.1228
# Test Loss: 1.1794
# Epoch [12/50], Iteration [100/782], Loss: 1.1622
# Epoch [12/50], Iteration [200/782], Loss: 1.1668
# Epoch [12/50], Iteration [300/782], Loss: 1.1439
# Epoch [12/50], Iteration [400/782], Loss: 1.1581
# Epoch [12/50], Iteration [500/782], Loss: 1.1685
# Epoch [12/50], Iteration [600/782], Loss: 1.1860
# Epoch [12/50], Iteration [700/782], Loss: 1.1557
# Epoch [12/50], Loss: 0.1214
# Test Loss: 1.1376
# Epoch [13/50], Iteration [100/782], Loss: 1.1621
# Epoch [13/50], Iteration [200/782], Loss: 1.1236
# Epoch [13/50], Iteration [300/782], Loss: 1.1363
# Epoch [13/50], Iteration [400/782], Loss: 1.1236
# Epoch [13/50], Iteration [500/782], Loss: 1.1192
# Epoch [13/50], Iteration [600/782], Loss: 1.1245
# Epoch [13/50], Iteration [700/782], Loss: 1.1306
# Epoch [13/50], Loss: 0.1182
# Test Loss: 1.1072
# Epoch [14/50], Iteration [100/782], Loss: 1.1232
# Epoch [14/50], Iteration [200/782], Loss: 1.0944
# Epoch [14/50], Iteration [300/782], Loss: 1.1236
# Epoch [14/50], Iteration [400/782], Loss: 1.1094
# Epoch [14/50], Iteration [500/782], Loss: 1.1281
# Epoch [14/50], Iteration [600/782], Loss: 1.1376
# Epoch [14/50], Iteration [700/782], Loss: 1.0917
# Epoch [14/50], Loss: 0.1175
# Test Loss: 1.1522
# Epoch [15/50], Iteration [100/782], Loss: 1.0930
# Epoch [15/50], Iteration [200/782], Loss: 1.0628
# Epoch [15/50], Iteration [300/782], Loss: 1.1209
# Epoch [15/50], Iteration [400/782], Loss: 1.1249
# Epoch [15/50], Iteration [500/782], Loss: 1.1231
# Epoch [15/50], Iteration [600/782], Loss: 1.0967
# Epoch [15/50], Iteration [700/782], Loss: 1.1202
# Epoch [15/50], Loss: 0.1172
# Test Loss: 1.1193
# Epoch [16/50], Iteration [100/782], Loss: 1.1019
# Epoch [16/50], Iteration [200/782], Loss: 1.0932
# Epoch [16/50], Iteration [300/782], Loss: 1.0870
# Epoch [16/50], Iteration [400/782], Loss: 1.0874
# Epoch [16/50], Iteration [500/782], Loss: 1.1060
# Epoch [16/50], Iteration [600/782], Loss: 1.1054
# Epoch [16/50], Iteration [700/782], Loss: 1.0790
# Epoch [16/50], Loss: 0.1143
# Test Loss: 1.0804
# Epoch [17/50], Iteration [100/782], Loss: 1.0921
# Epoch [17/50], Iteration [200/782], Loss: 1.0709
# Epoch [17/50], Iteration [300/782], Loss: 1.1006
# Epoch [17/50], Iteration [400/782], Loss: 1.0552
# Epoch [17/50], Iteration [500/782], Loss: 1.0757
# Epoch [17/50], Iteration [600/782], Loss: 1.0965
# Epoch [17/50], Iteration [700/782], Loss: 1.0957
# Epoch [17/50], Loss: 0.1109
# Test Loss: 1.0950
# Epoch [18/50], Iteration [100/782], Loss: 1.0544
# Epoch [18/50], Iteration [200/782], Loss: 1.0589
# Epoch [18/50], Iteration [300/782], Loss: 1.0861
# Epoch [18/50], Iteration [400/782], Loss: 1.0794
# Epoch [18/50], Iteration [500/782], Loss: 1.0747
# Epoch [18/50], Iteration [600/782], Loss: 1.0756
# Epoch [18/50], Iteration [700/782], Loss: 1.0930
# Epoch [18/50], Loss: 0.1122
# Test Loss: 1.0821
# Epoch [19/50], Iteration [100/782], Loss: 1.0649
# Epoch [19/50], Iteration [200/782], Loss: 1.0632
# Epoch [19/50], Iteration [300/782], Loss: 1.0656
# Epoch [19/50], Iteration [400/782], Loss: 1.0316
# Epoch [19/50], Iteration [500/782], Loss: 1.0728
# Epoch [19/50], Iteration [600/782], Loss: 1.0744
# Epoch [19/50], Iteration [700/782], Loss: 1.0727
# Epoch [19/50], Loss: 0.1147
# Test Loss: 1.0849
# Epoch [20/50], Iteration [100/782], Loss: 1.0537
# Epoch [20/50], Iteration [200/782], Loss: 1.0598
# Epoch [20/50], Iteration [300/782], Loss: 1.0639
# Epoch [20/50], Iteration [400/782], Loss: 1.0779
# Epoch [20/50], Iteration [500/782], Loss: 1.0666
# Epoch [20/50], Iteration [600/782], Loss: 1.0736
# Epoch [20/50], Iteration [700/782], Loss: 1.0546
# Epoch [20/50], Loss: 0.1088
# Test Loss: 1.0951
# Epoch [21/50], Iteration [100/782], Loss: 1.0321
# Epoch [21/50], Iteration [200/782], Loss: 1.0581
# Epoch [21/50], Iteration [300/782], Loss: 1.0347
# Epoch [21/50], Iteration [400/782], Loss: 1.0479
# Epoch [21/50], Iteration [500/782], Loss: 1.0234
# Epoch [21/50], Iteration [600/782], Loss: 1.0517
# Epoch [21/50], Iteration [700/782], Loss: 1.0738
# Epoch [21/50], Loss: 0.1114
# Test Loss: 1.1276
# Epoch [22/50], Iteration [100/782], Loss: 1.0443
# Epoch [22/50], Iteration [200/782], Loss: 1.0216
# Epoch [22/50], Iteration [300/782], Loss: 1.0508
# Epoch [22/50], Iteration [400/782], Loss: 1.0527
# Epoch [22/50], Iteration [500/782], Loss: 1.0440
# Epoch [22/50], Iteration [600/782], Loss: 1.0403
# Epoch [22/50], Iteration [700/782], Loss: 1.0295
# Epoch [22/50], Loss: 0.1073
# Test Loss: 1.0610
# Epoch [23/50], Iteration [100/782], Loss: 1.0341
# Epoch [23/50], Iteration [200/782], Loss: 1.0227
# Epoch [23/50], Iteration [300/782], Loss: 1.0542
# Epoch [23/50], Iteration [400/782], Loss: 1.0277
# Epoch [23/50], Iteration [500/782], Loss: 1.0451
# Epoch [23/50], Iteration [600/782], Loss: 1.0354
# Epoch [23/50], Iteration [700/782], Loss: 1.0517
# Epoch [23/50], Loss: 0.1093
# Test Loss: 1.1210
# Epoch [24/50], Iteration [100/782], Loss: 1.0543
# Epoch [24/50], Iteration [200/782], Loss: 1.0276
# Epoch [24/50], Iteration [300/782], Loss: 1.0274
# Epoch [24/50], Iteration [400/782], Loss: 1.0251
# Epoch [24/50], Iteration [500/782], Loss: 1.0227
# Epoch [24/50], Iteration [600/782], Loss: 1.0282
# Epoch [24/50], Iteration [700/782], Loss: 1.0264
# Epoch [24/50], Loss: 0.1075
# Test Loss: 1.0544
# Epoch [25/50], Iteration [100/782], Loss: 1.0293
# Epoch [25/50], Iteration [200/782], Loss: 1.0175
# Epoch [25/50], Iteration [300/782], Loss: 1.0173
# Epoch [25/50], Iteration [400/782], Loss: 1.0127
# Epoch [25/50], Iteration [500/782], Loss: 1.0152
# Epoch [25/50], Iteration [600/782], Loss: 1.0218
# Epoch [25/50], Iteration [700/782], Loss: 1.0268
# Epoch [25/50], Loss: 0.1073
# Test Loss: 1.0615
# Epoch [26/50], Iteration [100/782], Loss: 1.0413
# Epoch [26/50], Iteration [200/782], Loss: 1.0183
# Epoch [26/50], Iteration [300/782], Loss: 1.0153
# Epoch [26/50], Iteration [400/782], Loss: 1.0075
# Epoch [26/50], Iteration [500/782], Loss: 1.0438
# Epoch [26/50], Iteration [600/782], Loss: 1.0184
# Epoch [26/50], Iteration [700/782], Loss: 0.9877
# Epoch [26/50], Loss: 0.1094
# Test Loss: 1.1442
# Epoch [27/50], Iteration [100/782], Loss: 1.0339
# Epoch [27/50], Iteration [200/782], Loss: 1.0328
# Epoch [27/50], Iteration [300/782], Loss: 1.0334
# Epoch [27/50], Iteration [400/782], Loss: 1.0539
# Epoch [27/50], Iteration [500/782], Loss: 0.9884
# Epoch [27/50], Iteration [600/782], Loss: 1.0248
# Epoch [27/50], Iteration [700/782], Loss: 1.0344
# Epoch [27/50], Loss: 0.1038
# Test Loss: 1.1175
# Epoch [28/50], Iteration [100/782], Loss: 1.0274
# Epoch [28/50], Iteration [200/782], Loss: 1.0156
# Epoch [28/50], Iteration [300/782], Loss: 1.0140
# Epoch [28/50], Iteration [400/782], Loss: 1.0071
# Epoch [28/50], Iteration [500/782], Loss: 1.0010
# Epoch [28/50], Iteration [600/782], Loss: 1.0284
# Epoch [28/50], Iteration [700/782], Loss: 1.0204
# Epoch [28/50], Loss: 0.1078
# Test Loss: 1.0164
# Epoch [29/50], Iteration [100/782], Loss: 1.0157
# Epoch [29/50], Iteration [200/782], Loss: 1.0126
# Epoch [29/50], Iteration [300/782], Loss: 1.0167
# Epoch [29/50], Iteration [400/782], Loss: 1.0095
# Epoch [29/50], Iteration [500/782], Loss: 1.0212
# Epoch [29/50], Iteration [600/782], Loss: 0.9951
# Epoch [29/50], Iteration [700/782], Loss: 0.9981
# Epoch [29/50], Loss: 0.1078
# Test Loss: 1.0347
# Epoch [30/50], Iteration [100/782], Loss: 1.0067
# Epoch [30/50], Iteration [200/782], Loss: 1.0071
# Epoch [30/50], Iteration [300/782], Loss: 0.9642
# Epoch [30/50], Iteration [400/782], Loss: 1.0198
# Epoch [30/50], Iteration [500/782], Loss: 1.0095
# Epoch [30/50], Iteration [600/782], Loss: 1.0236
# Epoch [30/50], Iteration [700/782], Loss: 0.9931
# Epoch [30/50], Loss: 0.1074
# Test Loss: 1.1054
# Epoch [31/50], Iteration [100/782], Loss: 0.9981
# Epoch [31/50], Iteration [200/782], Loss: 0.9955
# Epoch [31/50], Iteration [300/782], Loss: 1.0058
# Epoch [31/50], Iteration [400/782], Loss: 0.9822
# Epoch [31/50], Iteration [500/782], Loss: 0.9763
# Epoch [31/50], Iteration [600/782], Loss: 1.0170
# Epoch [31/50], Iteration [700/782], Loss: 1.0039
# Epoch [31/50], Loss: 0.1080
# Test Loss: 1.0630
# Epoch [32/50], Iteration [100/782], Loss: 1.0173
# Epoch [32/50], Iteration [200/782], Loss: 1.0299
# Epoch [32/50], Iteration [300/782], Loss: 0.9834
# Epoch [32/50], Iteration [400/782], Loss: 0.9989
# Epoch [32/50], Iteration [500/782], Loss: 1.0021
# Epoch [32/50], Iteration [600/782], Loss: 0.9853
# Epoch [32/50], Iteration [700/782], Loss: 0.9710
# Epoch [32/50], Loss: 0.1036
# Test Loss: 1.0768
# Epoch [33/50], Iteration [100/782], Loss: 1.0077
# Epoch [33/50], Iteration [200/782], Loss: 0.9799
# Epoch [33/50], Iteration [300/782], Loss: 0.9793
# Epoch [33/50], Iteration [400/782], Loss: 0.9824
# Epoch [33/50], Iteration [500/782], Loss: 0.9929
# Epoch [33/50], Iteration [600/782], Loss: 0.9887
# Epoch [33/50], Iteration [700/782], Loss: 0.9946
# Epoch [33/50], Loss: 0.1039
# Test Loss: 1.0532
# Epoch [34/50], Iteration [100/782], Loss: 0.9976
# Epoch [34/50], Iteration [200/782], Loss: 1.0039
# Epoch [34/50], Iteration [300/782], Loss: 1.0062
# Epoch [34/50], Iteration [400/782], Loss: 1.0011
# Epoch [34/50], Iteration [500/782], Loss: 0.9734
# Epoch [34/50], Iteration [600/782], Loss: 0.9890
# Epoch [34/50], Iteration [700/782], Loss: 1.0026
# Epoch [34/50], Loss: 0.1017
# Test Loss: 1.0449
# Epoch [35/50], Iteration [100/782], Loss: 1.0163
# Epoch [35/50], Iteration [200/782], Loss: 0.9768
# Epoch [35/50], Iteration [300/782], Loss: 0.9931
# Epoch [35/50], Iteration [400/782], Loss: 1.0017
# Epoch [35/50], Iteration [500/782], Loss: 0.9928
# Epoch [35/50], Iteration [600/782], Loss: 0.9810
# Epoch [35/50], Iteration [700/782], Loss: 1.0053
# Epoch [35/50], Loss: 0.1041
# Test Loss: 1.0623
# Epoch [36/50], Iteration [100/782], Loss: 0.9811
# Epoch [36/50], Iteration [200/782], Loss: 0.9854
# Epoch [36/50], Iteration [300/782], Loss: 0.9922
# Epoch [36/50], Iteration [400/782], Loss: 0.9758
# Epoch [36/50], Iteration [500/782], Loss: 0.9897
# Epoch [36/50], Iteration [600/782], Loss: 0.9784
# Epoch [36/50], Iteration [700/782], Loss: 0.9760
# Epoch [36/50], Loss: 0.1019
# Test Loss: 1.0416
# Epoch [37/50], Iteration [100/782], Loss: 0.9848
# Epoch [37/50], Iteration [200/782], Loss: 0.9924
# Epoch [37/50], Iteration [300/782], Loss: 0.9622
# Epoch [37/50], Iteration [400/782], Loss: 0.9777
# Epoch [37/50], Iteration [500/782], Loss: 0.9826
# Epoch [37/50], Iteration [600/782], Loss: 0.9917
# Epoch [37/50], Iteration [700/782], Loss: 1.0000
# Epoch [37/50], Loss: 0.1031
# Test Loss: 1.0209
# Epoch [38/50], Iteration [100/782], Loss: 0.9653
# Epoch [38/50], Iteration [200/782], Loss: 1.0166
# Epoch [38/50], Iteration [300/782], Loss: 0.9882
# Epoch [38/50], Iteration [400/782], Loss: 0.9726
# Epoch [38/50], Iteration [500/782], Loss: 0.9776
# Epoch [38/50], Iteration [600/782], Loss: 0.9753
# Epoch [38/50], Iteration [700/782], Loss: 0.9913
# Epoch [38/50], Loss: 0.0997
# Test Loss: 1.0252
# Epoch [39/50], Iteration [100/782], Loss: 0.9792
# Epoch [39/50], Iteration [200/782], Loss: 0.9772
# Epoch [39/50], Iteration [300/782], Loss: 0.9727
# Epoch [39/50], Iteration [400/782], Loss: 0.9714
# Epoch [39/50], Iteration [500/782], Loss: 0.9743
# Epoch [39/50], Iteration [600/782], Loss: 0.9840
# Epoch [39/50], Iteration [700/782], Loss: 0.9672
# Epoch [39/50], Loss: 0.1042
# Test Loss: 1.0197
# Epoch [40/50], Iteration [100/782], Loss: 0.9725
# Epoch [40/50], Iteration [200/782], Loss: 0.9790
# Epoch [40/50], Iteration [300/782], Loss: 0.9702
# Epoch [40/50], Iteration [400/782], Loss: 0.9619
# Epoch [40/50], Iteration [500/782], Loss: 0.9684
# Epoch [40/50], Iteration [600/782], Loss: 0.9758
# Epoch [40/50], Iteration [700/782], Loss: 0.9777
# Epoch [40/50], Loss: 0.1032
# Test Loss: 1.0311
# Epoch [41/50], Iteration [100/782], Loss: 0.9832
# Epoch [41/50], Iteration [200/782], Loss: 0.9777
# Epoch [41/50], Iteration [300/782], Loss: 0.9506
# Epoch [41/50], Iteration [400/782], Loss: 0.9671
# Epoch [41/50], Iteration [500/782], Loss: 0.9723
# Epoch [41/50], Iteration [600/782], Loss: 0.9814
# Epoch [41/50], Iteration [700/782], Loss: 0.9661
# Epoch [41/50], Loss: 0.1034
# Test Loss: 1.0548
# Epoch [42/50], Iteration [100/782], Loss: 0.9750
# Epoch [42/50], Iteration [200/782], Loss: 0.9735
# Epoch [42/50], Iteration [300/782], Loss: 0.9484
# Epoch [42/50], Iteration [400/782], Loss: 0.9631
# Epoch [42/50], Iteration [500/782], Loss: 0.9747
# Epoch [42/50], Iteration [600/782], Loss: 0.9438
# Epoch [42/50], Iteration [700/782], Loss: 0.9837
# Epoch [42/50], Loss: 0.1007
# Test Loss: 1.0093
# Epoch [43/50], Iteration [100/782], Loss: 0.9632
# Epoch [43/50], Iteration [200/782], Loss: 0.9498
# Epoch [43/50], Iteration [300/782], Loss: 0.9466
# Epoch [43/50], Iteration [400/782], Loss: 0.9962
# Epoch [43/50], Iteration [500/782], Loss: 0.9762
# Epoch [43/50], Iteration [600/782], Loss: 0.9689
# Epoch [43/50], Iteration [700/782], Loss: 0.9788
# Epoch [43/50], Loss: 0.1019
# Test Loss: 0.9947
# Epoch [44/50], Iteration [100/782], Loss: 0.9702
# Epoch [44/50], Iteration [200/782], Loss: 0.9771
# Epoch [44/50], Iteration [300/782], Loss: 0.9635
# Epoch [44/50], Iteration [400/782], Loss: 0.9623
# Epoch [44/50], Iteration [500/782], Loss: 0.9656
# Epoch [44/50], Iteration [600/782], Loss: 1.0005
# Epoch [44/50], Iteration [700/782], Loss: 0.9827
# Epoch [44/50], Loss: 0.1022
# Test Loss: 1.0277
# Epoch [45/50], Iteration [100/782], Loss: 0.9623
# Epoch [45/50], Iteration [200/782], Loss: 0.9519
# Epoch [45/50], Iteration [300/782], Loss: 0.9463
# Epoch [45/50], Iteration [400/782], Loss: 0.9844
# Epoch [45/50], Iteration [500/782], Loss: 0.9725
# Epoch [45/50], Iteration [600/782], Loss: 0.9833
# Epoch [45/50], Iteration [700/782], Loss: 0.9764
# Epoch [45/50], Loss: 0.1027
# Test Loss: 1.0152
# Epoch [46/50], Iteration [100/782], Loss: 0.9573
# Epoch [46/50], Iteration [200/782], Loss: 0.9684
# Epoch [46/50], Iteration [300/782], Loss: 0.9845
# Epoch [46/50], Iteration [400/782], Loss: 0.9425
# Epoch [46/50], Iteration [500/782], Loss: 0.9607
# Epoch [46/50], Iteration [600/782], Loss: 0.9705
# Epoch [46/50], Iteration [700/782], Loss: 0.9745
# Epoch [46/50], Loss: 0.1017
# Test Loss: 1.0388
# Epoch [47/50], Iteration [100/782], Loss: 0.9482
# Epoch [47/50], Iteration [200/782], Loss: 0.9478
# Epoch [47/50], Iteration [300/782], Loss: 0.9706
# Epoch [47/50], Iteration [400/782], Loss: 0.9399
# Epoch [47/50], Iteration [500/782], Loss: 0.9701
# Epoch [47/50], Iteration [600/782], Loss: 0.9666
# Epoch [47/50], Iteration [700/782], Loss: 0.9554
# Epoch [47/50], Loss: 0.1008
# Test Loss: 1.0128
# Epoch [48/50], Iteration [100/782], Loss: 0.9515
# Epoch [48/50], Iteration [200/782], Loss: 0.9744
# Epoch [48/50], Iteration [300/782], Loss: 0.9814
# Epoch [48/50], Iteration [400/782], Loss: 0.9352
# Epoch [48/50], Iteration [500/782], Loss: 0.9617
# Epoch [48/50], Iteration [600/782], Loss: 0.9680
# Epoch [48/50], Iteration [700/782], Loss: 0.9472
# Epoch [48/50], Loss: 0.1027
# Test Loss: 1.0189
# Epoch [49/50], Iteration [100/782], Loss: 0.9516
# Epoch [49/50], Iteration [200/782], Loss: 0.9609
# Epoch [49/50], Iteration [300/782], Loss: 0.9342
# Epoch [49/50], Iteration [400/782], Loss: 0.9434
# Epoch [49/50], Iteration [500/782], Loss: 0.9576
# Epoch [49/50], Iteration [600/782], Loss: 1.0020
# Epoch [49/50], Iteration [700/782], Loss: 0.9378
# Epoch [49/50], Loss: 0.0998
# Test Loss: 0.9933
# Epoch [50/50], Iteration [100/782], Loss: 0.9406
# Epoch [50/50], Iteration [200/782], Loss: 0.9509
# Epoch [50/50], Iteration [300/782], Loss: 0.9329
# Epoch [50/50], Iteration [400/782], Loss: 0.9747
# Epoch [50/50], Iteration [500/782], Loss: 0.9529
# Epoch [50/50], Iteration [600/782], Loss: 0.9484
# Epoch [50/50], Iteration [700/782], Loss: 0.9539
# Epoch [50/50], Loss: 0.1007
# Test Loss: 1.0117
# Accuracy of the model on the 10,000 test images: 63.00%

# %%
plt.plot(losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
